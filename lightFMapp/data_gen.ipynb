# %%
import pandas as pd
import numpy as np
import random

# %%
columns = ["userId", "productId", "rating", "timestamp"]
ratings = pd.DataFrame(columns = columns)

# %%
ratingz = []
for j in range(100):
    for i in range(100):
        userId = j
        productId = 100+i
        rating = random.randint(0,5)
        timestamp = str(random.randint(0,12))+str(random.randint(0,60))+str(random.randint(0,60))
        ratings.loc[i] = [userId,productId,rating,timestamp]
    counter = 0

# %%
ratings.to_csv("ratings.csv")

# %%
def create_interaction_matrix(df,user_col, item_col, rating_col, norm= False, threshold = None):
    '''
    Function to create an interaction matrix dataframe from transactional type interactions
    Required Input -
        - df = Pandas DataFrame containing user-item interactions
        - user_col = column name containing user's identifier
        - item_col = column name containing item's identifier
        - rating col = column name containing user feedback on interaction with a given item
        - norm (optional) = True if a normalization of ratings is needed
        - threshold (required if norm = True) = value above which the rating is favorable
    Expected output - 
        - Pandas dataframe with user-item interactions ready to be fed in a recommendation algorithm
    '''
    interactions = df.groupby([user_col, item_col])[rating_col] \
            .sum().unstack().reset_index(). \
            fillna(0).set_index(user_col)
    if norm:
        interactions = interactions.applymap(lambda x: 1 if x > threshold else 0)
    return interactions

# %%
interactions = create_interaction_matrix(df = ratings,
                                         user_col = 'userId',
                                         item_col = 'productId',
                                         rating_col = 'rating',
                                         threshold = '3')
interactions.shape
# Out:
# (1, 100)

# %%
interactions
# Out:
# productId  100  101  102  103  104  105  106  107  108  109  ...  190  191  \
# userId                                                       ...
# 1            4    3    3    4    2    5    2    0    3    2  ...    3    2
#
# productId  192  193  194  195  196  197  198  199
# userId
# 1            5    1    0    1    0    1    4    3
#
# [1 rows x 100 columns]

# %%
def create_user_dict(interactions):
    '''
    Function to create a user dictionary based on their index and number in interaction dataset
    Required Input - 
        interactions - dataset create by create_interaction_matrix
    Expected Output -
        user_dict - Dictionary type output containing interaction_index as key and user_id as value
    '''
    user_id = list(interactions.index)
    user_dict = {}
    counter = 0 
    for i in user_id:
        user_dict[i] = counter
        counter += 1
    return user_dict

# %%
user_dict = create_user_dict(interactions=interactions)

# %%
user_dict
# Out:
# {1: 0}

# %%
data_prod = pd.read_csv("product_db")

# %%
data_prod
# Out:
#      product_id                              product_name product_category  \
# 0             0            DelkaMaleblueshirtoff #EROP418            shirt
# 1             1       VersaceUnisexgreenpantsoff #PRPO492            pants
# 2             2      VersaceFemalewhitejeansslim #AVIN370            jeans
# 3             3       ArmaniUnisexwhitelowersoff #PRPO471           lowers
# 4             4  BaldwinsFemaleblackjeansregular #ORAV195            jeans
# ..          ...                                       ...              ...
# 495         495      VersaceMaleredlowersregular #PSPO449           lowers
# 496         496       ArrowFemaleblacklowersslim #ORAV427           lowers
# 497         497      LevisMaleyellowpantsregular #PRPO499            pants
# 498         498        AdidasMaleredpantsregular #QWIO145            pants
# 499         499  UnderArmourFemaleblacklowersoff #EROP114           lowers
#
#     product_brand product_color  product_price  product_CTR  \
# 0           Delka          blue            600           23
# 1         Versace         green            300           14
# 2         Versace         white            200           11
# 3          Armani         white           1400           51
# 4        Baldwins         black            800           49
# ..            ...           ...            ...          ...
# 495       Versace           red           1500           98
# 496         Arrow         black            750           36
# 497         Levis        yellow            300           63
# 498        Adidas           red            250           26
# 499   UnderArmour         black            300           36
#
#      product_add_to_carts  product_units_sold
# 0                       5                   6
# 1                      12                   5
# 2                      16                   9
# 3                       6                  12
# 4                       9                   3
# ..                    ...                 ...
# 495                     2                  12
# 496                    16                   6
# 497                    15                   6
# 498                    16                   7
# 499                    15                   0
#
# [500 rows x 9 columns]

# %%
def create_item_dict(df,id_col,name_col):
    '''
    Function to create an item dictionary based on their item_id and item name
    Required Input - 
        - df = Pandas dataframe with Item information
        - id_col = Column name containing unique identifier for an item
        - name_col = Column name containing name of the item
    Expected Output -
        item_dict = Dictionary type output containing item_id as key and item_name as value
    '''
    item_dict ={}
    for i in range(df.shape[0]):
        item_dict[(df.loc[i,id_col])] = df.loc[i,name_col]
    return item_dict

# %%
products_dict = create_item_dict(df = data_prod,
                               id_col = 'product_id',
                               name_col = 'product_name')

# %%
products_dict
# Out:
# {0: 'DelkaMaleblueshirtoff #EROP418',
#  1: 'VersaceUnisexgreenpantsoff #PRPO492',
#  2: 'VersaceFemalewhitejeansslim #AVIN370',
#  3: 'ArmaniUnisexwhitelowersoff #PRPO471',
#  4: 'BaldwinsFemaleblackjeansregular #ORAV195',
#  5: 'LevisFemaleredjeansslim #EROP356',
#  6: 'Ralph LaurenFemalegreenshirtoff #AVIN152',
#  7: 'AdidasFemaleblackt-shirtregular #ORAV218',
#  8: 'BaldwinsUnisexbluet-shirtoff #PRPO305',
#  9: 'American GiantMaleyellowt-shirtoff #PSPO234',
#  10: 'LevisMalebluepantsregular #ORAV121',
#  11: 'VersaceUnisexredshirtregular #QWIO107',
#  12: 'UnderArmourMaleredt-shirtoff #EROP474',
#  13: 'PumaUnisexgreenjeansregular #AVIN324',
#  14: 'UnderArmourFemaleredt-shirtregular #PRPO200',
#  15: 'PumaMaleredlowersoff #PSPO201',
#  16: 'AdidasUnisexyellowshirtregular #PSPO424',
#  17: 'VersaceUnisexblacklowersoff #ORAV205',
#  18: '0ne8Unisexblackshirtslim #QWIO404',
#  19: 'Ralph LaurenMaleyellowlowersregular #EROP449',
#  20: "Emily'sFemaleyellowt-shirtoff #PRPO435",
#  21: 'American GiantUnisexredjeansregular #AVIN309',
#  22: 'ArmaniUnisexgreenpantsoff #QWIO477',
#  23: 'BrooksUnisexyellowjeansslim #PSPO299',
#  24: 'ArrowUnisexbluelowersslim #AVIN248',
#  25: 'Ebbets Field FlannelsMalegreenjeansoff #ORAV271',
#  26: 'VersaceFemalewhitejeansregular #ORAV157',
#  27: 'LevisUnisexbluelowersslim #EROP365',
#  28: 'American GiantUnisexblackpantsslim #PSPO361',
#  29: 'LevisMalewhitet-shirtregular #ORAV349',
#  30: 'UnderArmourUnisexgreenpantsregular #PRPO200',
#  31: 'DelkaMaleyellowt-shirtoff #PSPO112',
#  32: 'VersaceUnisexredlowersoff #ORAV119',
#  33: 'DelkaMalewhiteshirtoff #AVIN414',
#  34: 'ArmaniUnisexwhitelowersoff #AVIN273',
#  35: 'PumaMalebluet-shirtregular #PSPO310',
#  36: "Emily'sFemaleredlowersregular #PRPO131",
#  37: 'DelkaUnisexblackjeansregular #PRPO197',
#  38: 'ArmaniMalebluepantsregular #AVIN164',
#  39: 'AdidasMaleredpantsregular #ORAV174',
#  40: 'American GiantUnisexbluet-shirtregular #PSPO172',
#  41: 'BrooksMalebluepantsregular #EROP409',
#  42: 'Ralph LaurenUnisexredt-shirtslim #PSPO140',
#  43: 'Ebbets Field FlannelsMaleblacklowersslim #PSPO250',
#  44: 'ArmaniFemalebluepantsregular #QWIO233',
#  45: '0ne8Unisexwhiteshirtslim #PSPO149',
#  46: 'VersaceMaleyellowt-shirtslim #AVIN117',
#  47: 'VersaceUnisexbluepantsoff #PRPO201',
#  48: 'UnderArmourFemalebluepantsregular #QWIO396',
#  49: 'UnderArmourUnisexgreent-shirtslim #PSPO335',
#  50: 'Ebbets Field FlannelsUnisexbluepantsregular #ORAV165',
#  51: 'ArmaniFemalebluet-shirtoff #PRPO276',
#  52: 'BaldwinsUnisexyellowshirtoff #PSPO388',
#  53: 'PumaMalebluejeansregular #AVIN104',
#  54: 'BillsMalebluejeansregular #PSPO170',
#  55: "Emily'sFemalewhiteshirtoff #QWIO435",
#  56: 'UnderArmourFemaleyellowlowersoff #PSPO253',
#  57: 'PumaUnisexredshirtslim #PSPO151',
#  58: 'BaldwinsMaleyellowjeansoff #QWIO422',
#  59: 'LevisFemalewhitelowersoff #ORAV448',
#  60: 'VersaceMaleblueshirtoff #AVIN430',
#  61: 'BrooksMaleyellowpantsslim #AVIN201',
#  62: 'BaldwinsFemaleredt-shirtslim #ORAV288',
#  63: 'BaldwinsFemaleyellowpantsoff #PRPO395',
#  64: '0ne8Unisexyellowpantsoff #EROP428',
#  65: 'AdidasUnisexwhiteshirtslim #QWIO131',
#  66: 'BaldwinsUnisexyellowlowersoff #PSPO355',
#  67: "Emily'sUnisexblackt-shirtregular #PSPO209",
#  68: 'BrooksFemalebluejeansregular #QWIO105',
#  69: 'Ebbets Field FlannelsUnisexgreenpantsoff #PRPO482',
#  70: 'UnderArmourFemaleyellowt-shirtoff #EROP210',
#  71: 'ArmaniFemalewhitejeansoff #ORAV220',
#  72: 'VersaceMalewhitelowersoff #AVIN299',
#  73: '0ne8Malebluepantsoff #QWIO293',
#  74: 'ArmaniMalebluet-shirtslim #PSPO203',
#  75: 'PumaMalegreenshirtregular #EROP401',
#  76: 'Ralph LaurenMaleblackshirtregular #PRPO489',
#  77: 'Ralph LaurenMaleblacklowersoff #PSPO159',
#  78: 'PumaFemaleredpantsoff #AVIN224',
#  79: 'ArmaniMalegreent-shirtoff #EROP162',
#  80: 'AdidasMaleyellowt-shirtoff #PSPO195',
#  81: 'ArrowFemaleredt-shirtslim #AVIN388',
#  82: "Emily'sMaleblackjeansslim #ORAV398",
#  83: 'AdidasFemalegreenshirtoff #ORAV443',
#  84: 'NikeMaleblackt-shirtslim #PSPO100',
#  85: 'BrooksUnisexwhitet-shirtoff #QWIO287',
#  86: 'BaldwinsFemalegreent-shirtslim #QWIO365',
#  87: "Emily'sMaleyellowlowersslim #ORAV211",
#  88: 'American GiantFemaleblackpantsoff #PRPO317',
#  89: 'BillsMaleblackpantsoff #PRPO228',
#  90: 'Ebbets Field FlannelsUnisexgreenjeansoff #PRPO403',
#  91: 'American GiantFemaleredpantsslim #PRPO201',
#  92: 'PumaFemaleredpantsslim #QWIO361',
#  93: 'LevisUnisexwhitepantsregular #ORAV218',
#  94: 'VersaceFemaleblackpantsoff #PRPO245',
#  95: 'American GiantUnisexwhitejeansoff #ORAV325',
#  96: 'BrooksFemalewhitejeansregular #EROP176',
#  97: 'PumaMalewhitelowersregular #AVIN387',
#  98: 'BaldwinsFemaleyellowjeansregular #AVIN348',
#  99: 'BillsUnisexwhitepantsoff #AVIN100',
#  100: 'NikeUnisexwhiteshirtregular #AVIN160',
#  101: 'UnderArmourFemaleblackpantsregular #EROP492',
#  102: 'DelkaUnisexyellowt-shirtoff #PRPO326',
#  103: 'ArrowUnisexredjeansregular #PSPO290',
#  104: "Emily'sMalebluelowersslim #ORAV408",
#  105: 'VersaceMalegreenjeansregular #EROP155',
#  106: 'Ebbets Field FlannelsFemaleredpantsregular #QWIO244',
#  107: 'UnderArmourFemaleredshirtslim #AVIN154',
#  108: 'UnderArmourUnisexyellowjeansslim #ORAV363',
#  109: 'BaldwinsUnisexblackshirtoff #PSPO469',
#  110: '0ne8Maleblackshirtregular #PSPO463',
#  111: 'NikeUnisexyellowpantsregular #EROP490',
#  112: 'ArmaniMalegreenlowersregular #ORAV394',
#  113: 'DelkaUnisexredshirtoff #PSPO401',
#  114: 'Ralph LaurenMaleyellowpantsoff #EROP418',
#  115: 'BillsUnisexwhitejeansslim #PSPO390',
#  116: 'BillsFemaleredlowersoff #PSPO183',
#  117: 'ArrowUnisexblackshirtoff #QWIO169',
#  118: 'VersaceUnisexwhiteshirtslim #PRPO260',
#  119: 'Ebbets Field FlannelsFemalegreent-shirtoff #AVIN490',
#  120: 'BaldwinsFemalegreenjeansoff #PRPO405',
#  121: 'AdidasFemalegreenjeansoff #QWIO422',
#  122: 'ArmaniMalegreenjeansslim #PSPO217',
#  123: 'BaldwinsMaleblueshirtoff #PRPO115',
#  124: 'American GiantUnisexblackpantsslim #ORAV283',
#  125: 'NikeFemaleblacklowersslim #AVIN447',
#  126: 'ArrowFemaleredlowersslim #PSPO440',
#  127: 'ArrowUnisexyellowjeansslim #ORAV268',
#  128: 'VersaceFemalewhitet-shirtoff #QWIO329',
#  129: 'DelkaFemalewhitelowersslim #ORAV127',
#  130: 'American GiantUnisexyellowpantsregular #PSPO406',
#  131: 'Ebbets Field FlannelsUnisexblacklowersoff #ORAV255',
#  132: 'Ebbets Field FlannelsFemaleyellowshirtoff #PSPO307',
#  133: 'PumaUnisexredlowersoff #AVIN178',
#  134: 'DelkaUnisexblackshirtslim #AVIN140',
#  135: '0ne8Femaleyellowt-shirtslim #PSPO207',
#  136: 'American GiantMaleredlowersregular #ORAV293',
#  137: 'VersaceMalegreent-shirtoff #EROP473',
#  138: 'BaldwinsUnisexwhitelowersoff #QWIO158',
#  139: 'American GiantUnisexredjeansoff #AVIN482',
#  140: 'Ebbets Field FlannelsFemalegreenpantsslim #EROP194',
#  141: 'ArmaniMaleblackshirtoff #PRPO125',
#  142: 'Ralph LaurenFemalewhitepantsregular #PSPO163',
#  143: 'PumaMaleblackshirtslim #EROP243',
#  144: '0ne8Malegreenjeansslim #PRPO412',
#  145: 'LevisFemalegreenlowersregular #EROP156',
#  146: "Emily'sFemaleblacklowersslim #EROP435",
#  147: 'Ralph LaurenMalebluejeansregular #PSPO291',
#  148: "Emily'sMalewhitet-shirtregular #EROP110",
#  149: 'ArmaniMaleyellowpantsregular #AVIN263',
#  150: "Emily'sMalebluejeansregular #AVIN302",
#  151: '0ne8Maleblackjeansregular #ORAV401',
#  152: 'AdidasMalegreenpantsoff #PRPO274',
#  153: 'ArmaniFemaleblacklowersslim #EROP394',
#  154: 'UnderArmourUnisexyellowpantsregular #PSPO180',
#  155: "Emily'sFemaleredpantsregular #PSPO270",
#  156: 'Ebbets Field FlannelsUnisexwhitejeansslim #EROP349',
#  157: 'ArmaniUnisexyellowshirtregular #ORAV485',
#  158: 'DelkaFemaleblueshirtslim #PRPO482',
#  159: 'ArrowFemaleredjeansregular #EROP253',
#  160: 'AdidasFemaleredlowersslim #PRPO190',
#  161: 'ArmaniMaleredlowersslim #EROP293',
#  162: 'BrooksUnisexredpantsoff #PRPO452',
#  163: 'VersaceFemaleyellowt-shirtregular #EROP347',
#  164: 'UnderArmourMaleredt-shirtslim #ORAV448',
#  165: 'NikeUnisexblackt-shirtregular #PSPO346',
#  166: 'ArmaniMaleblackt-shirtoff #AVIN353',
#  167: 'AdidasMalebluejeansregular #PSPO312',
#  168: "Emily'sMalebluet-shirtslim #EROP236",
#  169: 'Ebbets Field FlannelsMaleyellowshirtregular #PRPO225',
#  170: 'BrooksMaleblackshirtslim #ORAV496',
#  171: 'BrooksMaleblackt-shirtregular #QWIO243',
#  172: 'BaldwinsMalegreent-shirtregular #ORAV328',
#  173: 'ArmaniUnisexbluejeansoff #AVIN355',
#  174: "Emily'sFemaleyellowlowersregular #ORAV178",
#  175: 'LevisMalebluelowersoff #ORAV419',
#  176: 'NikeMalebluepantsregular #ORAV140',
#  177: 'Ebbets Field FlannelsMaleblacklowersslim #PRPO339',
#  178: 'NikeFemaleredpantsoff #PRPO496',
#  179: 'BrooksFemaleredpantsslim #QWIO291',
#  180: 'DelkaFemalewhitelowersregular #PRPO377',
#  181: 'Ralph LaurenUnisexblacklowersregular #EROP176',
#  182: 'VersaceUnisexredshirtslim #PSPO226',
#  183: 'ArmaniFemaleredjeansslim #PRPO448',
#  184: 'VersaceUnisexyellowjeansregular #QWIO131',
#  185: 'Ebbets Field FlannelsUnisexredt-shirtoff #PRPO345',
#  186: 'Ralph LaurenMaleblackpantsoff #PSPO136',
#  187: 'DelkaFemaleblackpantsslim #ORAV164',
#  188: 'ArmaniUnisexyellowshirtslim #PSPO107',
#  189: 'American GiantMaleblackpantsslim #PRPO245',
#  190: 'PumaMaleyellowpantsslim #ORAV461',
#  191: 'LevisUnisexredshirtregular #PSPO119',
#  192: 'VersaceMalebluet-shirtoff #PSPO114',
#  193: 'NikeMaleblacklowersoff #ORAV176',
#  194: 'DelkaUnisexgreent-shirtslim #QWIO312',
#  195: 'American GiantMalegreenshirtregular #AVIN478',
#  196: 'AdidasMalewhitejeansslim #AVIN173',
#  197: 'BaldwinsMaleyellowlowersslim #PRPO407',
#  198: 'BillsFemalewhitepantsoff #AVIN456',
#  199: 'Ebbets Field FlannelsFemaleredpantsregular #PSPO324',
#  200: 'ArrowUnisexblacklowersregular #AVIN188',
#  201: 'VersaceUnisexredlowersoff #QWIO495',
#  202: 'BaldwinsMaleyellowpantsoff #QWIO384',
#  203: 'VersaceMalebluet-shirtoff #PSPO165',
#  204: 'BrooksUnisexwhitepantsoff #EROP250',
#  205: 'BrooksMaleblackshirtslim #QWIO175',
#  206: 'UnderArmourFemalewhiteshirtoff #AVIN183',
#  207: 'ArrowUnisexredt-shirtregular #PRPO427',
#  208: 'Ralph LaurenUnisexwhitet-shirtregular #QWIO497',
#  209: 'American GiantFemalebluet-shirtslim #PSPO333',
#  210: 'PumaFemalebluet-shirtoff #EROP206',
#  211: 'BillsFemalewhitelowersoff #AVIN228',
#  212: 'BrooksFemaleyellowshirtoff #ORAV122',
#  213: 'Ralph LaurenMaleyellowt-shirtslim #ORAV308',
#  214: 'Ebbets Field FlannelsFemaleredpantsslim #AVIN277',
#  215: 'UnderArmourMalebluet-shirtslim #QWIO324',
#  216: 'NikeFemalewhitejeansoff #PSPO148',
#  217: 'UnderArmourUnisexredshirtregular #QWIO209',
#  218: 'DelkaMalegreenlowersregular #EROP124',
#  219: "Emily'sUnisexblackt-shirtregular #ORAV466",
#  220: 'BrooksMalebluepantsslim #AVIN365',
#  221: 'BaldwinsFemaleyellowlowersoff #EROP381',
#  222: 'NikeFemalegreenjeansoff #ORAV132',
#  223: 'BrooksFemaleyellowlowersoff #PSPO270',
#  224: 'American GiantUnisexwhitelowersslim #PSPO350',
#  225: 'PumaFemalewhitelowersoff #EROP315',
#  226: 'ArmaniUnisexredshirtoff #QWIO479',
#  227: 'PumaFemaleredt-shirtregular #ORAV183',
#  228: 'BillsMalewhitejeansslim #PRPO262',
#  229: 'BrooksMalewhitet-shirtregular #PRPO434',
#  230: 'NikeFemalebluelowersoff #PSPO415',
#  231: 'LevisMaleyellowjeansslim #ORAV494',
#  232: 'ArrowUnisexgreenjeansslim #EROP481',
#  233: '0ne8Unisexblackpantsregular #AVIN183',
#  234: 'Ebbets Field FlannelsUnisexwhitelowersregular #QWIO368',
#  235: 'American GiantFemaleyellowpantsoff #AVIN201',
#  236: 'BrooksFemalewhitejeansoff #QWIO422',
#  237: 'Ralph LaurenUnisexredjeansslim #QWIO499',
#  238: 'LevisUnisexblackt-shirtslim #PSPO321',
#  239: 'American GiantMaleredt-shirtoff #EROP148',
#  240: 'NikeFemaleblacklowersregular #AVIN197',
#  241: 'BillsMaleblackpantsoff #QWIO359',
#  242: 'Ebbets Field FlannelsUnisexgreent-shirtoff #PRPO325',
#  243: 'PumaMaleredjeansregular #PRPO178',
#  244: 'AdidasUnisexblackpantsregular #QWIO343',
#  245: 'Ebbets Field FlannelsFemaleredlowersregular #PRPO472',
#  246: 'BillsUnisexgreenpantsregular #QWIO358',
#  247: 'NikeFemalegreenshirtoff #AVIN202',
#  248: 'PumaFemaleyellowlowersoff #PSPO169',
#  249: 'BaldwinsFemaleredt-shirtregular #ORAV213',
#  250: 'PumaFemaleredshirtslim #ORAV288',
#  251: 'ArmaniMaleblackjeansregular #PSPO114',
#  252: 'VersaceUnisexbluejeansoff #PRPO279',
#  253: 'BillsMalewhitejeansoff #PSPO265',
#  254: 'BillsUnisexblacklowersslim #ORAV447',
#  255: 'ArmaniMaleredlowersregular #QWIO222',
#  256: 'BaldwinsUnisexgreenlowersslim #AVIN102',
#  257: 'American GiantMalebluejeansregular #ORAV342',
#  258: 'BaldwinsMalewhitepantsoff #PRPO249',
#  259: 'LevisUnisexgreenshirtregular #PSPO496',
#  260: 'ArmaniUnisexyellowshirtoff #ORAV359',
#  261: 'Ebbets Field FlannelsUnisexwhiteshirtslim #QWIO270',
#  262: 'AdidasUnisexgreenpantsregular #AVIN448',
#  263: 'ArmaniMalegreenlowersoff #AVIN232',
#  264: 'ArmaniMalewhitet-shirtslim #QWIO382',
#  265: 'ArmaniUnisexwhitelowersoff #AVIN430',
#  266: 'American GiantMaleredlowersslim #EROP334',
#  267: 'PumaFemalebluet-shirtoff #PRPO123',
#  268: 'VersaceFemaleyellowjeansregular #AVIN348',
#  269: 'Ralph LaurenUnisexwhitejeansregular #QWIO173',
#  270: 'UnderArmourMalegreenshirtregular #EROP325',
#  271: 'BillsUnisexredt-shirtoff #QWIO283',
#  272: 'ArmaniUnisexblackjeansoff #EROP156',
#  273: 'LevisMalebluejeansregular #EROP273',
#  274: 'AdidasFemaleredlowersslim #QWIO424',
#  275: 'LevisMaleblueshirtoff #AVIN125',
#  276: 'ArmaniMaleyellowt-shirtslim #ORAV358',
#  277: 'ArmaniMalewhitejeansoff #AVIN499',
#  278: 'BaldwinsFemaleblackt-shirtoff #PSPO170',
#  279: "Emily'sFemalegreenshirtslim #EROP425",
#  280: 'BillsFemalewhiteshirtoff #PSPO422',
#  281: 'PumaUnisexredt-shirtslim #EROP266',
#  282: 'BaldwinsUnisexyellowlowersregular #PRPO431',
#  283: 'BaldwinsUnisexblackshirtregular #PRPO445',
#  284: 'PumaUnisexblackshirtregular #PRPO281',
#  285: 'UnderArmourMaleredpantsoff #PRPO281',
#  286: 'DelkaUnisexyellowshirtoff #QWIO284',
#  287: 'VersaceUnisexredshirtregular #QWIO246',
#  288: 'VersaceUnisexbluet-shirtslim #PSPO129',
#  289: 'Ebbets Field FlannelsFemalebluelowersslim #PSPO280',
#  290: 'VersaceUnisexyellowlowersregular #PRPO467',
#  291: 'NikeFemalebluepantsregular #ORAV309',
#  292: 'UnderArmourMalegreenshirtoff #PRPO411',
#  293: 'BrooksUnisexyellowjeansslim #AVIN457',
#  294: "Emily'sUnisexgreenlowersregular #EROP279",
#  295: 'ArmaniFemaleblackjeansoff #PSPO470',
#  296: 'VersaceMalegreenshirtoff #EROP327',
#  297: 'ArmaniMalegreenpantsregular #ORAV112',
#  298: 'LevisMaleyellowt-shirtoff #QWIO425',
#  299: 'LevisMaleblackjeansoff #QWIO208',
#  300: 'BrooksMaleredshirtregular #PRPO100',
#  301: 'ArmaniFemaleblacklowersregular #ORAV319',
#  302: 'BrooksMaleredt-shirtregular #PRPO330',
#  303: 'ArmaniFemalebluet-shirtslim #EROP144',
#  304: 'LevisUnisexwhitejeansslim #QWIO476',
#  305: 'ArrowMalegreent-shirtslim #QWIO236',
#  306: 'PumaMalegreenlowersoff #EROP315',
#  307: 'Ebbets Field FlannelsUnisexgreenpantsregular #QWIO360',
#  308: 'Ebbets Field FlannelsUnisexgreenlowersregular #AVIN113',
#  309: 'LevisMaleyellowlowersoff #EROP444',
#  310: 'BaldwinsMaleblueshirtoff #PSPO303',
#  311: 'ArmaniUnisexgreenpantsregular #PRPO452',
#  312: 'ArrowMalewhitejeansoff #AVIN110',
#  313: 'BaldwinsMalegreenshirtslim #EROP376',
#  314: "Emily'sFemalebluet-shirtslim #PSPO156",
#  315: 'NikeUnisexredshirtregular #AVIN177',
#  316: 'VersaceUnisexblackshirtslim #PSPO117',
#  317: 'PumaMalewhitelowersslim #ORAV153',
#  318: 'PumaMalebluelowersslim #ORAV343',
#  319: 'AdidasFemaleblackjeansoff #PRPO317',
#  320: 'ArrowMalebluepantsslim #QWIO281',
#  321: 'DelkaMalewhitepantsregular #EROP348',
#  322: 'AdidasFemaleyellowjeansslim #QWIO406',
#  323: 'LevisUnisexblackshirtslim #AVIN233',
#  324: 'Ralph LaurenUnisexgreenjeansoff #ORAV281',
#  325: 'ArmaniUnisexbluepantsoff #AVIN417',
#  326: 'VersaceFemaleredt-shirtslim #EROP284',
#  327: 'VersaceFemaleblackjeansoff #PRPO396',
#  328: '0ne8Femalegreent-shirtslim #QWIO200',
#  329: 'ArmaniUnisexyellowlowersregular #PRPO185',
#  330: "Emily'sMaleblackshirtslim #AVIN245",
#  331: 'LevisUnisexwhitet-shirtslim #ORAV268',
#  332: '0ne8Malewhitejeansoff #PSPO356',
#  333: 'VersaceUnisexredshirtoff #QWIO157',
#  334: 'ArmaniUnisexgreenpantsregular #QWIO231',
#  335: 'VersaceFemaleblueshirtoff #ORAV234',
#  336: 'Ebbets Field FlannelsUnisexgreenpantsslim #AVIN359',
#  337: 'BrooksUnisexblackjeansoff #QWIO400',
#  338: 'ArmaniFemaleredshirtslim #PRPO278',
#  339: '0ne8Femalegreenpantsregular #ORAV192',
#  340: 'LevisUnisexwhitelowersslim #PRPO135',
#  341: 'ArrowUnisexblackjeansslim #PSPO113',
#  342: 'BillsMalegreent-shirtslim #PRPO117',
#  343: 'VersaceUnisexyellowjeansslim #PRPO436',
#  344: 'LevisFemalegreenlowersoff #EROP225',
#  345: "Emily'sUnisexbluelowersregular #ORAV375",
#  346: 'American GiantUnisexbluelowersoff #PRPO387',
#  347: 'BillsFemaleblueshirtoff #PRPO303',
#  348: 'BaldwinsMaleyellowshirtoff #ORAV444',
#  349: 'BrooksFemaleyellowpantsslim #EROP363',
#  350: 'BillsMaleredt-shirtslim #PSPO480',
#  351: 'LevisMaleredjeansregular #AVIN109',
#  352: 'NikeFemaleyellowt-shirtoff #AVIN373',
#  353: '0ne8Femalebluelowersregular #PSPO307',
#  354: 'Ebbets Field FlannelsFemalegreenpantsregular #AVIN425',
#  355: 'LevisMaleyellowt-shirtoff #AVIN482',
#  356: 'VersaceMaleblackjeansregular #AVIN199',
#  357: 'LevisFemalegreenpantsregular #ORAV284',
#  358: 'LevisMaleblackjeansregular #ORAV329',
#  359: 'AdidasUnisexblackpantsslim #PRPO248',
#  360: 'ArmaniFemaleblackpantsslim #EROP204',
#  361: 'VersaceUnisexyellowjeansregular #PRPO406',
#  362: 'American GiantFemaleblackshirtoff #EROP184',
#  363: 'LevisUnisexredshirtregular #PSPO226',
#  364: 'Ebbets Field FlannelsUnisexwhitejeansoff #ORAV163',
#  365: 'ArmaniMaleyellowpantsoff #ORAV381',
#  366: "Emily'sMalegreent-shirtoff #EROP212",
#  367: '0ne8Maleyellowshirtoff #ORAV353',
#  368: 'UnderArmourFemaleblackshirtregular #PSPO468',
#  369: 'LevisMaleyellowlowersregular #AVIN433',
#  370: 'ArmaniMalebluejeansoff #QWIO249',
#  371: 'ArrowUnisexbluelowersslim #QWIO287',
#  372: 'LevisUnisexbluet-shirtoff #QWIO109',
#  373: "Emily'sUnisexbluet-shirtregular #PRPO496",
#  374: 'PumaMalewhiteshirtoff #AVIN117',
#  375: 'Ralph LaurenUnisexgreent-shirtslim #AVIN291',
#  376: 'BillsMaleyellowshirtslim #PSPO316',
#  377: 'LevisMaleblackpantsregular #EROP102',
#  378: 'BillsMaleblacklowersslim #PRPO319',
#  379: 'AdidasMaleredshirtslim #PRPO170',
#  380: 'ArmaniUnisexyellowt-shirtslim #EROP382',
#  381: 'VersaceMalewhiteshirtregular #ORAV472',
#  382: 'ArrowFemaleyellowlowersslim #AVIN489',
#  383: 'BaldwinsUnisexwhiteshirtoff #EROP389',
#  384: 'American GiantUnisexwhitejeansregular #EROP129',
#  385: 'PumaMaleredpantsregular #EROP368',
#  386: 'NikeMaleredjeansoff #PRPO327',
#  387: 'American GiantMalewhitet-shirtoff #QWIO146',
#  388: 'ArmaniFemalewhitejeansregular #QWIO136',
#  389: 'Ralph LaurenMalewhitelowersregular #QWIO409',
#  390: 'UnderArmourMaleyellowlowersoff #AVIN101',
#  391: 'BillsMaleredlowersregular #PSPO421',
#  392: 'BillsFemalebluejeansregular #QWIO135',
#  393: 'BrooksFemaleblackjeansslim #AVIN133',
#  394: 'Ebbets Field FlannelsFemaleredpantsregular #QWIO362',
#  395: 'BaldwinsMaleredjeansregular #QWIO177',
#  396: 'ArrowFemaleyellowlowersregular #PRPO269',
#  397: 'DelkaFemaleblacklowersslim #PSPO212',
#  398: 'ArmaniMalebluejeansregular #PSPO496',
#  399: "Emily'sMaleredjeansoff #QWIO297",
#  400: 'LevisFemaleredjeansslim #EROP239',
#  401: 'VersaceUnisexwhitejeansregular #QWIO480',
#  402: 'LevisMaleredpantsregular #PSPO109',
#  403: 'UnderArmourMalegreenjeansregular #AVIN374',
#  404: 'LevisMaleblackt-shirtslim #AVIN172',
#  405: 'Ralph LaurenMaleblackt-shirtregular #PRPO255',
#  406: 'BillsFemaleblackt-shirtoff #PSPO230',
#  407: 'BaldwinsMaleyellowshirtslim #AVIN237',
#  408: 'DelkaUnisexblackt-shirtslim #PSPO466',
#  409: 'American GiantMalebluejeansoff #PSPO212',
#  410: 'ArmaniFemalegreent-shirtregular #AVIN150',
#  411: "Emily'sUnisexyellowt-shirtslim #EROP276",
#  412: 'Ralph LaurenUnisexredjeansoff #EROP262',
#  413: "Emily'sMaleblackpantsregular #PSPO245",
#  414: 'DelkaFemalewhitejeansregular #EROP205',
#  415: 'Ebbets Field FlannelsFemaleyellowlowersoff #PSPO141',
#  416: 'LevisMaleredt-shirtslim #ORAV172',
#  417: "Emily'sMaleredpantsslim #AVIN467",
#  418: 'ArmaniMaleyellowpantsregular #QWIO103',
#  419: 'Ralph LaurenFemalewhitepantsregular #ORAV316',
#  420: 'VersaceMaleyellowt-shirtslim #ORAV264',
#  421: 'Ralph LaurenUnisexwhitejeansoff #QWIO300',
#  422: 'LevisFemalewhitejeansslim #AVIN212',
#  423: 'ArmaniMaleredshirtslim #AVIN328',
#  424: 'BillsMalegreenlowersslim #PSPO385',
#  425: 'BaldwinsMalebluelowersoff #PRPO168',
#  426: 'NikeMaleblackpantsslim #EROP454',
#  427: 'LevisUnisexbluepantsregular #PSPO441',
#  428: 'Ebbets Field FlannelsUnisexblueshirtregular #PSPO496',
#  429: 'BaldwinsFemalewhiteshirtoff #PSPO415',
#  430: 'American GiantUnisexredt-shirtoff #AVIN310',
#  431: 'VersaceMaleyellowlowersslim #QWIO458',
#  432: 'BrooksFemaleblackt-shirtoff #ORAV450',
#  433: 'BaldwinsFemaleblackt-shirtregular #AVIN275',
#  434: 'American GiantMalebluet-shirtslim #PSPO314',
#  435: 'BillsFemaleredjeansregular #AVIN221',
#  436: 'BaldwinsFemalewhitet-shirtslim #EROP180',
#  437: 'BrooksUnisexblacklowersoff #QWIO421',
#  438: '0ne8Femaleredt-shirtoff #PSPO278',
#  439: 'DelkaMaleyellowjeansoff #PSPO224',
#  440: 'BrooksUnisexblackshirtslim #PSPO151',
#  441: 'Ebbets Field FlannelsFemaleredshirtoff #QWIO494',
#  442: 'VersaceFemaleredshirtoff #ORAV365',
#  443: 'LevisFemalewhitejeansslim #PSPO344',
#  444: 'BillsFemalewhitepantsoff #EROP132',
#  445: 'BrooksUnisexwhitepantsoff #AVIN390',
#  446: 'VersaceUnisexgreenshirtoff #ORAV212',
#  447: 'UnderArmourUnisexredlowersoff #ORAV270',
#  448: '0ne8Femaleredpantsoff #EROP370',
#  449: 'UnderArmourUnisexwhitepantsoff #QWIO274',
#  450: 'ArrowUnisexwhitejeansregular #ORAV167',
#  451: 'BrooksMaleblackjeansoff #QWIO160',
#  452: 'BrooksFemaleblackpantsslim #QWIO408',
#  453: 'DelkaMaleyellowt-shirtslim #QWIO421',
#  454: "Emily'sFemaleredlowersregular #PSPO115",
#  455: 'ArrowMalegreenshirtregular #PSPO199',
#  456: 'AdidasFemalebluejeansregular #EROP270',
#  457: 'NikeUnisexwhitepantsoff #PRPO462',
#  458: 'BillsUnisexredt-shirtoff #PSPO260',
#  459: 'AdidasMaleredlowersregular #EROP148',
#  460: '0ne8Maleblackjeansslim #EROP241',
#  461: 'American GiantUnisexgreent-shirtslim #QWIO155',
#  462: 'Ebbets Field FlannelsMaleyellowt-shirtslim #PRPO414',
#  463: 'PumaUnisexyellowjeansoff #EROP139',
#  464: 'LevisMalewhitelowersregular #EROP266',
#  465: 'BrooksFemalegreenshirtslim #ORAV334',
#  466: 'BrooksMalebluejeansregular #PSPO403',
#  467: 'VersaceUnisexwhitelowersoff #ORAV419',
#  468: 'DelkaMaleblacklowersslim #PRPO318',
#  469: 'LevisUnisexgreenlowersoff #QWIO251',
#  470: 'AdidasFemalewhitepantsoff #PSPO442',
#  471: 'ArrowFemalewhitet-shirtregular #PRPO368',
#  472: 'ArrowFemaleyellowt-shirtslim #QWIO322',
#  473: 'AdidasFemaleblackjeansslim #PSPO463',
#  474: 'Ebbets Field FlannelsFemaleredlowersslim #EROP336',
#  475: 'PumaFemalebluet-shirtoff #EROP334',
#  476: 'Ebbets Field FlannelsUnisexredshirtslim #PRPO188',
#  477: 'LevisMaleyellowpantsslim #PRPO421',
#  478: 'ArrowFemalegreenlowersregular #QWIO139',
#  479: 'UnderArmourFemaleredshirtslim #PSPO383',
#  480: 'AdidasMaleredjeansoff #PRPO475',
#  481: 'AdidasFemalegreenjeansregular #QWIO204',
#  482: 'NikeFemaleblueshirtregular #AVIN357',
#  483: 'PumaMalewhitepantsslim #PRPO134',
#  484: 'VersaceMalewhitelowersslim #QWIO450',
#  485: 'VersaceMaleyellowlowersregular #PSPO390',
#  486: 'NikeFemaleblackt-shirtregular #QWIO273',
#  487: 'ArrowUnisexbluet-shirtoff #AVIN276',
#  488: 'American GiantUnisexblackjeansslim #PRPO409',
#  489: 'AdidasMalewhitet-shirtregular #AVIN489',
#  490: 'ArmaniFemaleblackshirtoff #AVIN240',
#  491: 'NikeMaleblackshirtregular #PSPO185',
#  492: 'PumaMalegreenjeansslim #AVIN227',
#  493: 'VersaceUnisexgreenlowersoff #ORAV449',
#  494: 'UnderArmourMalebluepantsslim #PSPO362',
#  495: 'VersaceMaleredlowersregular #PSPO449',
#  496: 'ArrowFemaleblacklowersslim #ORAV427',
#  497: 'LevisMaleyellowpantsregular #PRPO499',
#  498: 'AdidasMaleredpantsregular #QWIO145',
#  499: 'UnderArmourFemaleblacklowersoff #EROP114'}

# %%
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity
from lightfm import LightFM
def runMF(interactions, n_components=30, loss='warp', k=15, epoch=30,n_jobs = 4):
    '''
    Function to run matrix-factorization algorithm
    Required Input -
        - interactions = dataset create by create_interaction_matrix
        - n_components = number of embeddings you want to create to define Item and user
        - loss = loss function other options are logistic, brp
        - epoch = number of epochs to run 
        - n_jobs = number of cores used for execution 
    Expected Output  -
        Model - Trained model
    '''
    x = sparse.csr_matrix(interactions.values)
    model = LightFM(no_components= n_components, loss=loss,k=k)
    model.fit(x,epochs=epoch,num_threads = n_jobs)
    return model
# Out:
# /Users/ajayguru/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages/lightfm/_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(

# %%
mf_model = runMF(interactions = interactions,
                 n_components = 30,
                 loss = 'warp',
                 k = 15,
                 epoch = 30,
                 n_jobs = 4)

# %%
def sample_recommendation_user(model, interactions, user_id, user_dict, 
                               item_dict,threshold = 0,nrec_items = 10, show = True):
    '''
    Function to produce user recommendations
    Required Input - 
        - model = Trained matrix factorization model
        - interactions = dataset used for training the model
        - user_id = user ID for which we need to generate recommendation
        - user_dict = Dictionary type input containing interaction_index as key and user_id as value
        - item_dict = Dictionary type input containing item_id as key and item_name as value
        - threshold = value above which the rating is favorable in new interaction matrix
        - nrec_items = Number of output recommendation needed
    Expected Output - 
        - Prints list of items the given user has already bought
        - Prints list of N recommended items  which user hopefully will be interested in
    '''
    n_users, n_items = interactions.shape
    user_x = user_dict[user_id]
    scores = pd.Series(model.predict(user_x,np.arange(n_items)))
    scores.index = interactions.columns
    scores = list(pd.Series(scores.sort_values(ascending=False).index))
    
    known_items = list(pd.Series(interactions.loc[user_id,:] \
                                 [interactions.loc[user_id,:] > threshold].index) \
								 .sort_values(ascending=False))
    
    scores = [x for x in scores if x not in known_items]
    return_score_list = scores[0:nrec_items]
    known_items = list(pd.Series(known_items).apply(lambda x: item_dict[x]))
    scores = list(pd.Series(return_score_list).apply(lambda x: item_dict[x]))
    if show == True:
        print("Known Likes:")
        counter = 1
        for i in known_items:
            print(str(counter) + '- ' + i)
            counter+=1

        print("\n Recommended Items:")
        counter = 1
        for i in scores:
            print(str(counter) + '- ' + i)
            counter+=1
    return return_score_list

# %%
rec_list = sample_recommendation_user(model = mf_model, 
                                      interactions = interactions, 
                                      user_id = 1, 
                                      user_dict = user_dict,
                                      item_dict = products_dict, 
                                      threshold = 4,
                                      nrec_items = 10)
# Out:
# Known Likes:
# 1- VersaceMalebluet-shirtoff #PSPO114
# 2- ArmaniUnisexbluejeansoff #AVIN355
# 3- BrooksMaleblackt-shirtregular #QWIO243
# 4- Ebbets Field FlannelsMaleyellowshirtregular #PRPO225
# 5- DelkaFemaleblueshirtslim #PRPO482
# 6- AdidasMalegreenpantsoff #PRPO274
# 7- 0ne8Malegreenjeansslim #PRPO412
# 8- BaldwinsUnisexwhitelowersoff #QWIO158
# 9- American GiantUnisexyellowpantsregular #PSPO406
# 10- BaldwinsMaleblueshirtoff #PRPO115
# 11- NikeUnisexyellowpantsregular #EROP490
# 12- VersaceMalegreenjeansregular #EROP155
#
#  Recommended Items:
# 1- BaldwinsFemalegreenjeansoff #PRPO405
# 2- NikeMalebluepantsregular #ORAV140
# 3- Ralph LaurenMalebluejeansregular #PSPO291
# 4- American GiantMalegreenshirtregular #AVIN478
# 5- PumaUnisexredlowersoff #AVIN178
# 6- Ebbets Field FlannelsFemalegreenpantsslim #EROP194
# 7- PumaMaleyellowpantsslim #ORAV461
# 8- NikeUnisexblackt-shirtregular #PSPO346
# 9- ArmaniMaleyellowpantsregular #AVIN263
# 10- Ebbets Field FlannelsFemalegreent-shirtoff #AVIN490
